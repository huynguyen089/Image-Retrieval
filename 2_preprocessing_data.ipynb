# %% [markdown]
# ## 1. Categories data

# %%
import os

# %%
root_imgs_path = "static/img/"

# %%
dic_categories = {'scenery' : [], 'furniture' : [], 'animal' : [], 'plant' : []}

# %%
for path in os.listdir(root_imgs_path):
    c, name = path.split("_")
    if c in dic_categories.keys():
        dic_categories[c].append(name)

# %%
sum([len(dic_categories[c]) for c in dic_categories])
# Out:
# 124

# %%
dic_categories
# Out:
# {'scenery': ['Bay',
#   'cave',
#   'Cliff',
#   'cloud',
#   'desert',
#   'farmland',
#   'flowergarden',
#   'Forests',
#   'glacier',
#   'grassland',
#   'horizon',
#   'lighthouse',
#   'Mountains',
#   'river',
#   'sky',
#   'valley',
#   'volcano',
#   'waterfall'],
#  'furniture': ['ball',
#   'bed',
#   'book',
#   'Bookcase',
#   'Bowl',
#   'cabinet',
#   'cart',
#   'chair',
#   'chests',
#   'clock',
#   'Clothes',
#   'desks',
#   'fridge',
#   'pan',
#   'Piano',
#   'sofa',
#   'spoon',
#   'table',
#   'Umbrella'],
#  'animal': ['Alligator',
#   'Alpaca',
#   'Anteater',
#   'Ants',
#   'Bats',
#   'bear',
#   'Bee',
#   'bird',
#   'Buffalo',
#   'Butterfly',
#   'Camel',
#   'Cat',
#   'Caterpillar',
#   'Cheetah',
#   'Chicken',
#   'Civet',
#   'Cock',
#   'Cockroaches',
#   'Coral',
#   'cows',
#   'Crab',
#   'Dog',
#   'donkey',
#   'Dragonfly',
#   'Duck',
#   'Elephant',
#   'Fish',
#   'flamingo',
#   'Flies',
#   'fox',
#   'Frog',
#   'Giraffe',
#   'horse',
#   'Jellyfish',
#   'Lizard',
#   'Monkey',
#   'Mosquito',
#   'Owl',
#   'panda',
#   'Pangolins',
#   'pig',
#   'Rabbit',
#   'scorpion',
#   'shrimp',
#   'Snail',
#   'Snake',
#   'Spider',
#   'tiger',
#   'Turtle',
#   'Whale'],
#  'plant': ['Apple',
#   'Apricot',
#   'Bamboo',
#   'Banana',
#   'Bean',
#   'Bougainvillea',
#   'carrot',
#   'Clove',
#   'Coconut',
#   'CoffeePlant',
#   'Corn',
#   'CornelianTree',
#   'CottonPlant',
#   'Dogwood',
#   'Durian',
#   'Fern',
#   'Fig',
#   'Flax',
#   'Flower',
#   'Frangipani',
#   'Grass',
#   'Hibiscus',
#   'JackFruit',
#   'Lantana',
#   'Moss',
#   'Mushroom',
#   'OrchidTree',
#   'PalmTree',
#   'Pea',
#   'radish',
#   'RangoonCreeper',
#   'Reed',
#   'Rose',
#   'Tulip',
#   'watermelon',
#   'Weed',
#   'wheat']}

# %%
max_len = max([len(dic_categories[c]) for c in dic_categories])

# %%
max_len
# Out:
# 50

# %%
for c in dic_categories:
    dic_categories[c] += [""]*(max_len - len(dic_categories[c]))

# %%
import pandas as pd
df = pd.DataFrame(dic_categories)

# %%
df.to_csv("categories.csv", index=False)

# %% [markdown]
# ## 2. Preprocessing data

# %%
import os

# %%
dic_categories = {'animal' : [], 'plant' : [], 'furniture' : [], 'scenery' : []}

# %%
images_path = "images/"
for path in os.listdir(images_path):
    key, name = path.split("_")
    if key in dic_categories.keys():
        dic_categories[key].append(name)

# %%
import os
from PIL import Image
import numpy as np
import warnings
warnings.filterwarnings("ignore", "(Possibly )?corrupt EXIF data", UserWarning)
Image.MAX_IMAGE_PIXELS = None

# %%
images_path = "images/"
dic_categories = {'animal' : [], 'plant' : [], 'furniture' : [], 'scenery' : []}
count = 0

# %%
for folder in os.listdir(images_path):
    if folder.split("_")[0] in dic_categories:
        path = images_path + folder
        list_dir = [path + '/' + name for name in os.listdir(path) if name.endswith((".jpg", ".png", ".jpeg"))]
        for p in list_dir:
            try:
                img = Image.open(p).resize((224, 224)) # open the image file
                
                if img.width < 10:
                    print("Image too small: ", p)
                    os.remove(p) # chú ý chỗ này, mới đầu chạy phải comment lại không lỡ lỗi mất hết ảnh

                img.verify() # verify that it is, in fact an image
                

            except Exception:
                count += 1
                print("error: ", p)
                os.remove(p) # chú ý chỗ này, mới đầu chạy phải comment lại không lỡ lỗi mất hết ảnh
# Out:
# error:  images/animal_Monkey/0.30392287710744614.jpg
# error:  images/animal_Monkey/0.0140516942940766.jpg
# error:  images/animal_Monkey/0.36069056054612525.jpg
# error:  images/animal_Monkey/0.5810946162691609.jpg
# error:  images/animal_Monkey/0.6607577033005341.jpg
# error:  images/animal_Monkey/0.3590357640278954.jpg
# error:  images/animal_Monkey/0.606225645510666.jpg
# error:  images/animal_Monkey/0.8885526414978608.jpg
# error:  images/animal_Monkey/0.9284927879444578.jpg
# error:  images/animal_Monkey/0.474721475553752.jpg
# error:  images/animal_Monkey/0.8625793089476257.jpg
# error:  images/animal_Monkey/0.11527734241836507.jpg
# error:  images/animal_Monkey/0.5472583866710569.jpg
# error:  images/animal_Monkey/0.8925521512976844.jpg
# error:  images/animal_Monkey/0.549643096956581.jpg
# error:  images/animal_Monkey/0.633115409559056.jpg
# error:  images/animal_Monkey/0.9447686536161793.jpg
# error:  images/animal_Elephant/0.5758823557606376.jpg
# error:  images/animal_Elephant/0.11151175991397078.jpg
# error:  images/animal_Elephant/0.9066881568864732.jpg
# error:  images/animal_Elephant/0.7137590329982004.jpg
# error:  images/animal_Elephant/0.9072770814781554.jpg
# error:  images/animal_Elephant/0.030554163509404764.jpg
# error:  images/animal_Elephant/0.2689870278922877.jpg
# error:  images/animal_Elephant/0.831631274642256.jpg
# error:  images/animal_Elephant/0.6697638623953784.jpg
# error:  images/animal_Elephant/0.32646662191536635.jpg
# error:  images/animal_Elephant/0.2963542406015791.jpg
# error:  images/animal_Elephant/0.4162733809233784.jpg
# error:  images/animal_Elephant/0.13559959802036425.jpg
# error:  images/animal_Elephant/0.7171636546620968.jpg
# error:  images/animal_Elephant/0.36760758995492526.jpg
# error:  images/animal_Elephant/0.4929866423253706.jpg
# error:  images/animal_Elephant/0.01388016381909074.jpg
